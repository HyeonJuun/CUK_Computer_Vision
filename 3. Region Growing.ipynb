# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
src = cv2.imread('./data/bridge.jpg')
srcrgb = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)
mask = np.zeros((src.shape[0]+2, src.shape[1]+2), np.uint8)

seed = (180, 80)
newVal = 255
loDiff, upDiff = (5, 5, 5), (5, 5, 5)
floodeflags = cv2.FLOODFILL_MASK_ONLY
cv2.floodFill(src, mask, seedPoint=seed, newVal=newVal, loDiff=loDiff, upDiff=upDiff)
cv2.circle(src, seed, 2, (0, 255, 0), cv2.FILLED, cv2.LINE_AA);

plt.figure(figsize=(30, 30))
image1 = plt.subplot(1,2,1)
image1.set_title('Original')
plt.axis('off')
plt.imshow(srcrgb)

image2 = plt.subplot(1,2,2)
image2.set_title('MASK')
plt.axis('off')
plt.imshow(mask, cmap='gray')

# %%
src2 = cv2.imread('./data/duck.png')
mask = np.zeros((src.shape[0]+2, src.shape[1]+2), np.uint8)



def onMouse(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        seed = (x, y)
        r = np.random.randint(256)
        g = np.random.randint(256)
        b = np.random.randint(256)
        newVal = (b, g, r)
        retval = cv2.floodFill(src2, mask, seed,  newVal=newVal, loDiff=loDiff, upDiff=upDiff)
        cv2.imshow('src2', src2)

cv2.imshow('src2', src2)
cv2.setMouseCallback('src2', onMouse)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-12c25f879eaf> in onMouse(event, x, y, flags, param)
#      11         b = np.random.randint(256)
#      12         newVal = (b, g, r)
# ---> 13         retval = cv2.floodFill(src2, mask, seed,  newVal=newVal, loDiff=loDiff, upDiff=upDiff)
#      14         cv2.imshow('src2', src2)
#      15
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\floodfill.cpp:555: error: (-215:Assertion failed) mask.rows == size.height+2 && mask.cols == size.width+2 in function 'cv::floodFill'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-12c25f879eaf> in onMouse(event, x, y, flags, param)
#      11         b = np.random.randint(256)
#      12         newVal = (b, g, r)
# ---> 13         retval = cv2.floodFill(src2, mask, seed,  newVal=newVal, loDiff=loDiff, upDiff=upDiff)
#      14         cv2.imshow('src2', src2)
#      15
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\floodfill.cpp:555: error: (-215:Assertion failed) mask.rows == size.height+2 && mask.cols == size.width+2 in function 'cv::floodFill'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-12c25f879eaf> in onMouse(event, x, y, flags, param)
#      11         b = np.random.randint(256)
#      12         newVal = (b, g, r)
# ---> 13         retval = cv2.floodFill(src2, mask, seed,  newVal=newVal, loDiff=loDiff, upDiff=upDiff)
#      14         cv2.imshow('src2', src2)
#      15
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\floodfill.cpp:555: error: (-215:Assertion failed) mask.rows == size.height+2 && mask.cols == size.width+2 in function 'cv::floodFill'
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-12c25f879eaf> in onMouse(event, x, y, flags, param)
#      11         b = np.random.randint(256)
#      12         newVal = (b, g, r)
# ---> 13         retval = cv2.floodFill(src2, mask, seed,  newVal=newVal, loDiff=loDiff, upDiff=upDiff)
#      14         cv2.imshow('src2', src2)
#      15
#
# error: OpenCV(4.5.4-dev) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\floodfill.cpp:555: error: (-215:Assertion failed) mask.rows == size.height+2 && mask.cols == size.width+2 in function 'cv::floodFill'
